# %%
'''
Q.1 Write a program that reads a 4-digit integer and reverses all the digits in the integer.  For example, if an integer 
is 9324, the output should be 4239.   If the user enters a non 4-digit value, the program should print a message 
and exit.  A few sample interactions are shown below

'''
Pos = input('Please enter a positive four digit number :- ')
PosNo =int(Pos)
OriginalNo = PosNo
if (PosNo>0):
    if len(Pos) == 4 :
        reverseNo = 0
        while(PosNo > 0) :
            #print(PosNo)
            rem = PosNo % 10
            reverseNo = (reverseNo * 10) + rem
            PosNo = PosNo //10
        print(OriginalNo,'in reverse is',reverseNo)
    else :
        print('You have entered an invalid value')
        print('Exiting the program')
else :
        print('You have entered an invalid value')
        print('Exiting the program')

# %%
'''
Q.2 Write a Python program to calculate the sum of three given numbers, if the three number are all the same
then return thrice of their sum, otherwise return four times the sum.

'''

fNo = int(input('Enter the first two-digit no: '))
sNo = int(input('Enter the second two-digit no: '))
tNo = int(input('Enter the third two-digit no: '))
if((fNo == sNo) and (sNo == tNo)) :
   
    sumS = 3 * (fNo+sNo+tNo)
    #print('all nos are same>>>',sumS)
    print('Three times the sum of',fNo,',' ,sNo,'and ',tNo,'is ',sumS)
else :
    sumD = 4 * (fNo+sNo+tNo)
    print('Four times the sum of',fNo,',' ,sNo,'and ',tNo,'is ',sumD)

# %%
'''

Q.3 Write a Python program to find the median among three given numbers. Sample interaction is given below: 

'''
fNo = int(input('Enter the first no: '))
sNo = int(input('Enter the second no: '))
tNo = int(input('Enter the third no: '))

small = 0
medium = 0
large = 0

if fNo < sNo and fNo < tNo :
    small = fNo
    if sNo < tNo :
        medium = sNo
        large = tNo
    else :
        medium = tNo 
        large = sNo
elif sNo < fNo and sNo < tNo :
    small = sNo
    if fNo < tNo :
        medium = fNo
        large = tNo
    else :
        medium = tNo
        large = fNo
elif tNo < fNo and tNo < sNo :
    small = tNo
    if fNo < sNo :
        medium = fNo
        large = sNo
    else :
        medium = sNo
        large = fNo
#print('small :',small,'medium :',medium,'large :',large)

print('Median of above three numbers is : ',medium)

# %%
'''

Q4: Write a program that takes as input two opposite corners of a rectangle: (x1,y1) and (x2,y2).  Finally, the 
user is prompted for the coordinates of a third point (x,y). The program should print Boolean value True or False 
based on whether the point (x,y) lies inside the rectangle. If the point lies on the rectangle, the program should 
print False.

'''

x1 = int(input('Enter x1 : '))
y1 = int(input('Enter y1 : '))
x2 = int(input('Enter x2 : '))
y2 = int(input('Enter y2 : '))
x = int(input('Enter x : '))
y = int(input('Enter y : '))
flag=False
if x1 < x < x2 or x2 < x < x1:
    if y1 < y < y2 or y2 < y < y1:
        flag = True
print(flag)
